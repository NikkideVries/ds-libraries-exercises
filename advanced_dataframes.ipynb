# %% [markdown]
# ### Exercise 1

# %%
#import files:
import pandas as pd
import numpy as np

# %%
#import env
import env

# %% [markdown]
# Question 3: Create a function named get_db_url. It should accept a username, hostname, password, and database name and return a url connection string formatted like in the example at the start of this lesson.

# %%
def get_db_url(database):
    """
    this fuction will: 
    - take in a string database
    - return a string connection url to be used with sqlalchemy later
    """
    conn_url = f'mysql+pymysql://{env.user}:{env.password}@{env.host}/{database}'
    return conn_url

# %%
url = get_db_url('employees')

# %% [markdown]
# Quesetion 4: Use your function to obtain a connection to the employees database.

# %%
from sqlalchemy import text, create_engine

engine = create_engine(url)

query = text('SELECT * FROM employees LIMIT 5 OFFSET 50')

pd.read_sql(query, engine.connect())
# Out:
#    emp_no  birth_date first_name  last_name gender   hire_date
# 0   10051  1953-07-28   Hidefumi      Caine      M  1992-10-15
# 1   10052  1961-02-26     Heping     Nitsch      M  1988-05-21
# 2   10053  1954-09-13     Sanjiv   Zschoche      F  1986-02-04
# 3   10054  1957-04-04     Mayumi  Schueller      M  1995-03-13
# 4   10055  1956-06-06     Georgy     Dredge      M  1992-04-27

# %%
pd.read_sql('select * from employees limit 10', url)
# Out:
#    emp_no  birth_date first_name  last_name gender   hire_date
# 0   10001  1953-09-02     Georgi    Facello      M  1986-06-26
# 1   10002  1964-06-02    Bezalel     Simmel      F  1985-11-21
# 2   10003  1959-12-03      Parto    Bamford      M  1986-08-28
# 3   10004  1954-05-01  Chirstian    Koblick      M  1986-12-01
# 4   10005  1955-01-21    Kyoichi   Maliniak      M  1989-09-12
# 5   10006  1953-04-20     Anneke    Preusig      F  1989-06-02
# 6   10007  1957-05-23    Tzvetan  Zielinski      F  1989-02-10
# 7   10008  1958-02-19     Saniya   Kalloufi      M  1994-09-15
# 8   10009  1952-04-19     Sumant       Peac      F  1985-02-18
# 9   10010  1963-06-01  Duangkaew   Piveteau      F  1989-08-24

# %% [markdown]
# 5. Once you have successfully run a query:
#
# a. Intentionally make a typo in the database url. What kind of error message do you see?
#
# b. Intentionally make an error in your SQL query. What does the error message look like?

# %%
url = get_db_url('employes')
pd.read_sql('select * from employees limit 10', url)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:3280, in Engine._wrap_pool_connect(self, fn, connection)
#    3279 try:
# -> 3280     return fn()
#    3281 except dialect.dbapi.Error as e:
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/sqlalchemy/pool/base.py:310, in Pool.connect(self)
#     303 """Return a DBAPI connection from the pool.
#     304
#     305 The connection is instrumented such that when its
#    (...)
#     308
#     309 """
# --> 310 return _ConnectionFairy._checkout(self)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/sqlalchemy/pool/base.py:868, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     867 if not fairy:
# --> 868     fairy = _ConnectionRecord.checkout(pool)
#     870     fairy._pool = pool
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/sqlalchemy/pool/base.py:476, in _ConnectionRecord.checkout(cls, pool)
#     474 @classmethod
#     475 def checkout(cls, pool):
# --> 476     rec = pool._do_get()
#     477     try:
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/sqlalchemy/pool/impl.py:145, in QueuePool._do_get(self)
#     144 except:
# --> 145     with util.safe_reraise():
#     146         self._dec_overflow()
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/sqlalchemy/util/langhelpers.py:70, in safe_reraise.__exit__(self, type_, value, traceback)
#      69     if not self.warn_only:
# ---> 70         compat.raise_(
#      71             exc_value,
#      72             with_traceback=exc_tb,
#      73         )
#      74 else:
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/sqlalchemy/util/compat.py:208, in raise_(***failed resolving arguments***)
#     207 try:
# --> 208     raise exception
#     209 finally:
#     210     # credit to
#     211     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     212     # as the __traceback__ object creates a cycle
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/sqlalchemy/pool/impl.py:143, in QueuePool._do_get(self)
#     142 try:
# --> 143     return self._create_connection()
#     144 except:
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/sqlalchemy/pool/base.py:256, in Pool._create_connection(self)
#     254 """Called by subclasses to create a new ConnectionRecord."""
# --> 256 return _ConnectionRecord(self)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/sqlalchemy/pool/base.py:371, in _ConnectionRecord.__init__(self, pool, connect)
#     370 if connect:
# --> 371     self.__connect()
#     372 self.finalize_callback = deque()
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/sqlalchemy/pool/base.py:665, in _ConnectionRecord.__connect(self)
#     664 except Exception as e:
# --> 665     with util.safe_reraise():
#     666         pool.logger.debug("Error on connect(): %s", e)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/sqlalchemy/util/langhelpers.py:70, in safe_reraise.__exit__(self, type_, value, traceback)
#      69     if not self.warn_only:
# ---> 70         compat.raise_(
#      71             exc_value,
#      72             with_traceback=exc_tb,
#      73         )
#      74 else:
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/sqlalchemy/util/compat.py:208, in raise_(***failed resolving arguments***)
#     207 try:
# --> 208     raise exception
#     209 finally:
#     210     # credit to
#     211     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     212     # as the __traceback__ object creates a cycle
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/sqlalchemy/pool/base.py:661, in _ConnectionRecord.__connect(self)
#     660 self.starttime = time.time()
# --> 661 self.dbapi_connection = connection = pool._invoke_creator(self)
#     662 pool.logger.debug("Created new connection %r", connection)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/create.py:590, in create_engine.<locals>.connect(connection_record)
#     589             return connection
# --> 590 return dialect.connect(*cargs, **cparams)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/default.py:597, in DefaultDialect.connect(self, *cargs, **cparams)
#     595 def connect(self, *cargs, **cparams):
#     596     # inherits the docstring from interfaces.Dialect.connect
# --> 597     return self.dbapi.connect(*cargs, **cparams)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pymysql/connections.py:358, in Connection.__init__(self, user, password, host, database, unix_socket, port, charset, collation, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     357 else:
# --> 358     self.connect()
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pymysql/connections.py:664, in Connection.connect(self, sock)
#     663 self._get_server_information()
# --> 664 self._request_authentication()
#     666 # Send "SET NAMES" query on init for:
#     667 # - Ensure charaset (and collation) is set to the server.
#     668 #   - collation_id in handshake packet may be ignored.
#    (...)
#     677 # - https://github.com/wagtail/wagtail/issues/9477
#     678 # - https://zenn.dev/methane/articles/2023-mysql-collation (Japanese)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pymysql/connections.py:954, in Connection._request_authentication(self)
#     953 self.write_packet(data)
# --> 954 auth_packet = self._read_packet()
#     956 # if authentication method isn't accepted the first byte
#     957 # will have the octet 254
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pymysql/connections.py:772, in Connection._read_packet(self, packet_type)
#     771         self._result.unbuffered_active = False
# --> 772     packet.raise_for_error()
#     773 return packet
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pymysql/protocol.py:221, in MysqlPacket.raise_for_error(self)
#     220     print("errno =", errno)
# --> 221 err.raise_mysql_exception(self._data)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pymysql/err.py:143, in raise_mysql_exception(data)
#     142     errorclass = InternalError if errno < 1000 else OperationalError
# --> 143 raise errorclass(errno, errval)
#
# OperationalError: (1044, "Access denied for user 'tobias_2305'@'%%' to database 'employes'")
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[27], line 2
#       1 url = get_db_url('employes')
# ----> 2 pd.read_sql('select * from employees limit 10', url)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/io/sql.py:590, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     581     return pandas_sql.read_table(
#     582         sql,
#     583         index_col=index_col,
#    (...)
#     587         chunksize=chunksize,
#     588     )
#     589 else:
# --> 590     return pandas_sql.read_query(
#     591         sql,
#     592         index_col=index_col,
#     593         params=params,
#     594         coerce_float=coerce_float,
#     595         parse_dates=parse_dates,
#     596         chunksize=chunksize,
#     597     )
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/io/sql.py:1560, in SQLDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype)
#    1512 """
#    1513 Read SQL query into a DataFrame.
#    1514
#    (...)
#    1556
#    1557 """
#    1558 args = _convert_params(sql, params)
# -> 1560 result = self.execute(*args)
#    1561 columns = result.keys()
#    1563 if chunksize is not None:
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/io/sql.py:1405, in SQLDatabase.execute(self, *args, **kwargs)
#    1403 def execute(self, *args, **kwargs):
#    1404     """Simple passthrough to SQLAlchemy connectable"""
# -> 1405     return self.connectable.execution_options().execute(*args, **kwargs)
#
# File <string>:2, in execute(self, statement, *multiparams, **params)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/sqlalchemy/util/deprecations.py:402, in _decorate_with_warning.<locals>.warned(fn, *args, **kwargs)
#     400 if not skip_warning:
#     401     _warn_with_version(message, version, wtype, stacklevel=3)
# --> 402 return fn(*args, **kwargs)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:3175, in Engine.execute(self, statement, *multiparams, **params)
#    3149 @util.deprecated_20(
#    3150     ":meth:`_engine.Engine.execute`",
#    3151     alternative="All statement execution in SQLAlchemy 2.0 is performed "
#    (...)
#    3156 )
#    3157 def execute(self, statement, *multiparams, **params):
#    3158     """Executes the given construct and returns a
#    3159     :class:`_engine.CursorResult`.
#    3160
#    (...)
#    3173
#    3174     """
# -> 3175     connection = self.connect(close_with_result=True)
#    3176     return connection.execute(statement, *multiparams, **params)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:3234, in Engine.connect(self, close_with_result)
#    3219 def connect(self, close_with_result=False):
#    3220     """Return a new :class:`_engine.Connection` object.
#    3221
#    3222     The :class:`_engine.Connection` object is a facade that uses a DBAPI
#    (...)
#    3231
#    3232     """
# -> 3234     return self._connection_cls(self, close_with_result=close_with_result)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:96, in Connection.__init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events, _allow_revalidate)
#      91     self._has_events = _branch_from._has_events
#      92 else:
#      93     self._dbapi_connection = (
#      94         connection
#      95         if connection is not None
# ---> 96         else engine.raw_connection()
#      97     )
#      99     self._transaction = self._nested_transaction = None
#     100     self.__savepoint_seq = 0
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:3313, in Engine.raw_connection(self, _connection)
#    3291 def raw_connection(self, _connection=None):
#    3292     """Return a "raw" DBAPI connection from the connection pool.
#    3293
#    3294     The returned object is a proxied version of the DBAPI
#    (...)
#    3311
#    3312     """
# -> 3313     return self._wrap_pool_connect(self.pool.connect, _connection)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:3283, in Engine._wrap_pool_connect(self, fn, connection)
#    3281 except dialect.dbapi.Error as e:
#    3282     if connection is None:
# -> 3283         Connection._handle_dbapi_exception_noconnection(
#    3284             e, dialect, self
#    3285         )
#    3286     else:
#    3287         util.raise_(
#    3288             sys.exc_info()[1], with_traceback=sys.exc_info()[2]
#    3289         )
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:2117, in Connection._handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    2115     util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2116 elif should_wrap:
# -> 2117     util.raise_(
#    2118         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2119     )
#    2120 else:
#    2121     util.raise_(exc_info[1], with_traceback=exc_info[2])
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/sqlalchemy/util/compat.py:208, in raise_(***failed resolving arguments***)
#     205     exception.__cause__ = replace_context
#     207 try:
# --> 208     raise exception
#     209 finally:
#     210     # credit to
#     211     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     212     # as the __traceback__ object creates a cycle
#     213     del exception, replace_context, from_, with_traceback
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:3280, in Engine._wrap_pool_connect(self, fn, connection)
#    3278 dialect = self.dialect
#    3279 try:
# -> 3280     return fn()
#    3281 except dialect.dbapi.Error as e:
#    3282     if connection is None:
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/sqlalchemy/pool/base.py:310, in Pool.connect(self)
#     302 def connect(self):
#     303     """Return a DBAPI connection from the pool.
#     304
#     305     The connection is instrumented such that when its
#    (...)
#     308
#     309     """
# --> 310     return _ConnectionFairy._checkout(self)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/sqlalchemy/pool/base.py:868, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     865 @classmethod
#     866 def _checkout(cls, pool, threadconns=None, fairy=None):
#     867     if not fairy:
# --> 868         fairy = _ConnectionRecord.checkout(pool)
#     870         fairy._pool = pool
#     871         fairy._counter = 0
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/sqlalchemy/pool/base.py:476, in _ConnectionRecord.checkout(cls, pool)
#     474 @classmethod
#     475 def checkout(cls, pool):
# --> 476     rec = pool._do_get()
#     477     try:
#     478         dbapi_connection = rec.get_connection()
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/sqlalchemy/pool/impl.py:145, in QueuePool._do_get(self)
#     143         return self._create_connection()
#     144     except:
# --> 145         with util.safe_reraise():
#     146             self._dec_overflow()
#     147 else:
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/sqlalchemy/util/langhelpers.py:70, in safe_reraise.__exit__(self, type_, value, traceback)
#      68     self._exc_info = None  # remove potential circular references
#      69     if not self.warn_only:
# ---> 70         compat.raise_(
#      71             exc_value,
#      72             with_traceback=exc_tb,
#      73         )
#      74 else:
#      75     if not compat.py3k and self._exc_info and self._exc_info[1]:
#      76         # emulate Py3K's behavior of telling us when an exception
#      77         # occurs in an exception handler.
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/sqlalchemy/util/compat.py:208, in raise_(***failed resolving arguments***)
#     205     exception.__cause__ = replace_context
#     207 try:
# --> 208     raise exception
#     209 finally:
#     210     # credit to
#     211     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     212     # as the __traceback__ object creates a cycle
#     213     del exception, replace_context, from_, with_traceback
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/sqlalchemy/pool/impl.py:143, in QueuePool._do_get(self)
#     141 if self._inc_overflow():
#     142     try:
# --> 143         return self._create_connection()
#     144     except:
#     145         with util.safe_reraise():
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/sqlalchemy/pool/base.py:256, in Pool._create_connection(self)
#     253 def _create_connection(self):
#     254     """Called by subclasses to create a new ConnectionRecord."""
# --> 256     return _ConnectionRecord(self)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/sqlalchemy/pool/base.py:371, in _ConnectionRecord.__init__(self, pool, connect)
#     369 self.__pool = pool
#     370 if connect:
# --> 371     self.__connect()
#     372 self.finalize_callback = deque()
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/sqlalchemy/pool/base.py:665, in _ConnectionRecord.__connect(self)
#     663     self.fresh = True
#     664 except Exception as e:
# --> 665     with util.safe_reraise():
#     666         pool.logger.debug("Error on connect(): %s", e)
#     667 else:
#     668     # in SQLAlchemy 1.4 the first_connect event is not used by
#     669     # the engine, so this will usually not be set
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/sqlalchemy/util/langhelpers.py:70, in safe_reraise.__exit__(self, type_, value, traceback)
#      68     self._exc_info = None  # remove potential circular references
#      69     if not self.warn_only:
# ---> 70         compat.raise_(
#      71             exc_value,
#      72             with_traceback=exc_tb,
#      73         )
#      74 else:
#      75     if not compat.py3k and self._exc_info and self._exc_info[1]:
#      76         # emulate Py3K's behavior of telling us when an exception
#      77         # occurs in an exception handler.
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/sqlalchemy/util/compat.py:208, in raise_(***failed resolving arguments***)
#     205     exception.__cause__ = replace_context
#     207 try:
# --> 208     raise exception
#     209 finally:
#     210     # credit to
#     211     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     212     # as the __traceback__ object creates a cycle
#     213     del exception, replace_context, from_, with_traceback
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/sqlalchemy/pool/base.py:661, in _ConnectionRecord.__connect(self)
#     659 try:
#     660     self.starttime = time.time()
# --> 661     self.dbapi_connection = connection = pool._invoke_creator(self)
#     662     pool.logger.debug("Created new connection %r", connection)
#     663     self.fresh = True
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/create.py:590, in create_engine.<locals>.connect(connection_record)
#     588         if connection is not None:
#     589             return connection
# --> 590 return dialect.connect(*cargs, **cparams)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/default.py:597, in DefaultDialect.connect(self, *cargs, **cparams)
#     595 def connect(self, *cargs, **cparams):
#     596     # inherits the docstring from interfaces.Dialect.connect
# --> 597     return self.dbapi.connect(*cargs, **cparams)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pymysql/connections.py:358, in Connection.__init__(self, user, password, host, database, unix_socket, port, charset, collation, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     356     self._sock = None
#     357 else:
# --> 358     self.connect()
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pymysql/connections.py:664, in Connection.connect(self, sock)
#     661 self._next_seq_id = 0
#     663 self._get_server_information()
# --> 664 self._request_authentication()
#     666 # Send "SET NAMES" query on init for:
#     667 # - Ensure charaset (and collation) is set to the server.
#     668 #   - collation_id in handshake packet may be ignored.
#    (...)
#     677 # - https://github.com/wagtail/wagtail/issues/9477
#     678 # - https://zenn.dev/methane/articles/2023-mysql-collation (Japanese)
#     679 self.set_character_set(self.charset, self.collation)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pymysql/connections.py:954, in Connection._request_authentication(self)
#     951     data += _lenenc_int(len(connect_attrs)) + connect_attrs
#     953 self.write_packet(data)
# --> 954 auth_packet = self._read_packet()
#     956 # if authentication method isn't accepted the first byte
#     957 # will have the octet 254
#     958 if auth_packet.is_auth_switch_request():
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pymysql/connections.py:772, in Connection._read_packet(self, packet_type)
#     770     if self._result is not None and self._result.unbuffered_active is True:
#     771         self._result.unbuffered_active = False
# --> 772     packet.raise_for_error()
#     773 return packet
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pymysql/protocol.py:221, in MysqlPacket.raise_for_error(self)
#     219 if DEBUG:
#     220     print("errno =", errno)
# --> 221 err.raise_mysql_exception(self._data)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pymysql/err.py:143, in raise_mysql_exception(data)
#     141 if errorclass is None:
#     142     errorclass = InternalError if errno < 1000 else OperationalError
# --> 143 raise errorclass(errno, errval)
#
# OperationalError: (pymysql.err.OperationalError) (1044, "Access denied for user 'tobias_2305'@'%%' to database 'employes'")
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %%
url = get_db_url('employees')
pd.read_sql('select * from employes limit 10', url)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1819, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1818     if not evt_handled:
# -> 1819         self.dialect.do_execute(
#    1820             cursor, statement, parameters, context
#    1821         )
#    1823 if self._has_events or self.engine._has_events:
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pymysql/cursors.py:153, in Cursor.execute(self, query, args)
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pymysql/cursors.py:322, in Cursor._query(self, q)
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pymysql/connections.py:558, in Connection.query(self, sql, unbuffered)
#     557 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 558 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     559 return self._affected_rows
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pymysql/connections.py:822, in Connection._read_query_result(self, unbuffered)
#     821     result = MySQLResult(self)
# --> 822     result.read()
#     823 self._result = result
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pymysql/connections.py:1200, in MySQLResult.read(self)
#    1199 try:
# -> 1200     first_packet = self.connection._read_packet()
#    1202     if first_packet.is_ok_packet():
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pymysql/connections.py:772, in Connection._read_packet(self, packet_type)
#     771         self._result.unbuffered_active = False
# --> 772     packet.raise_for_error()
#     773 return packet
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pymysql/protocol.py:221, in MysqlPacket.raise_for_error(self)
#     220     print("errno =", errno)
# --> 221 err.raise_mysql_exception(self._data)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pymysql/err.py:143, in raise_mysql_exception(data)
#     142     errorclass = InternalError if errno < 1000 else OperationalError
# --> 143 raise errorclass(errno, errval)
#
# ProgrammingError: (1146, "Table 'employees.employes' doesn't exist")
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[28], line 2
#       1 url = get_db_url('employees')
# ----> 2 pd.read_sql('select * from employes limit 10', url)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/io/sql.py:590, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     581     return pandas_sql.read_table(
#     582         sql,
#     583         index_col=index_col,
#    (...)
#     587         chunksize=chunksize,
#     588     )
#     589 else:
# --> 590     return pandas_sql.read_query(
#     591         sql,
#     592         index_col=index_col,
#     593         params=params,
#     594         coerce_float=coerce_float,
#     595         parse_dates=parse_dates,
#     596         chunksize=chunksize,
#     597     )
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/io/sql.py:1560, in SQLDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype)
#    1512 """
#    1513 Read SQL query into a DataFrame.
#    1514
#    (...)
#    1556
#    1557 """
#    1558 args = _convert_params(sql, params)
# -> 1560 result = self.execute(*args)
#    1561 columns = result.keys()
#    1563 if chunksize is not None:
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/io/sql.py:1405, in SQLDatabase.execute(self, *args, **kwargs)
#    1403 def execute(self, *args, **kwargs):
#    1404     """Simple passthrough to SQLAlchemy connectable"""
# -> 1405     return self.connectable.execution_options().execute(*args, **kwargs)
#
# File <string>:2, in execute(self, statement, *multiparams, **params)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/sqlalchemy/util/deprecations.py:402, in _decorate_with_warning.<locals>.warned(fn, *args, **kwargs)
#     400 if not skip_warning:
#     401     _warn_with_version(message, version, wtype, stacklevel=3)
# --> 402 return fn(*args, **kwargs)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:3176, in Engine.execute(self, statement, *multiparams, **params)
#    3158 """Executes the given construct and returns a
#    3159 :class:`_engine.CursorResult`.
#    3160
#    (...)
#    3173
#    3174 """
#    3175 connection = self.connect(close_with_result=True)
# -> 3176 return connection.execute(statement, *multiparams, **params)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1291, in Connection.execute(self, statement, *multiparams, **params)
#    1282 if isinstance(statement, util.string_types):
#    1283     util.warn_deprecated_20(
#    1284         "Passing a string to Connection.execute() is "
#    1285         "deprecated and will be removed in version 2.0.  Use the "
#    (...)
#    1288         "driver-level SQL string."
#    1289     )
# -> 1291     return self._exec_driver_sql(
#    1292         statement,
#    1293         multiparams,
#    1294         params,
#    1295         _EMPTY_EXECUTION_OPTS,
#    1296         future=False,
#    1297     )
#    1299 try:
#    1300     meth = statement._execute_on_connection
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1595, in Connection._exec_driver_sql(self, statement, multiparams, params, execution_options, future)
#    1585         (
#    1586             statement,
#    1587             distilled_params,
#    (...)
#    1591             statement, distilled_parameters, execution_options
#    1592         )
#    1594 dialect = self.dialect
# -> 1595 ret = self._execute_context(
#    1596     dialect,
#    1597     dialect.execution_ctx_cls._init_statement,
#    1598     statement,
#    1599     distilled_parameters,
#    1600     execution_options,
#    1601     statement,
#    1602     distilled_parameters,
#    1603 )
#    1605 if not future:
#    1606     if self._has_events or self.engine._has_events:
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1862, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1859             branched.close()
#    1861 except BaseException as e:
# -> 1862     self._handle_dbapi_exception(
#    1863         e, statement, parameters, cursor, context
#    1864     )
#    1866 return result
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:2043, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2041     util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2042 elif should_wrap:
# -> 2043     util.raise_(
#    2044         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2045     )
#    2046 else:
#    2047     util.raise_(exc_info[1], with_traceback=exc_info[2])
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/sqlalchemy/util/compat.py:208, in raise_(***failed resolving arguments***)
#     205     exception.__cause__ = replace_context
#     207 try:
# --> 208     raise exception
#     209 finally:
#     210     # credit to
#     211     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     212     # as the __traceback__ object creates a cycle
#     213     del exception, replace_context, from_, with_traceback
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1819, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1817                 break
#    1818     if not evt_handled:
# -> 1819         self.dialect.do_execute(
#    1820             cursor, statement, parameters, context
#    1821         )
#    1823 if self._has_events or self.engine._has_events:
#    1824     self.dispatch.after_cursor_execute(
#    1825         self,
#    1826         cursor,
#    (...)
#    1830         context.executemany,
#    1831     )
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pymysql/cursors.py:153, in Cursor.execute(self, query, args)
#     149     pass
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#     155 return result
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pymysql/cursors.py:322, in Cursor._query(self, q)
#     320 conn = self._get_db()
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#     324 return self.rowcount
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pymysql/connections.py:558, in Connection.query(self, sql, unbuffered)
#     556     sql = sql.encode(self.encoding, "surrogateescape")
#     557 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 558 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     559 return self._affected_rows
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pymysql/connections.py:822, in Connection._read_query_result(self, unbuffered)
#     820 else:
#     821     result = MySQLResult(self)
# --> 822     result.read()
#     823 self._result = result
#     824 if result.server_status is not None:
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pymysql/connections.py:1200, in MySQLResult.read(self)
#    1198 def read(self):
#    1199     try:
# -> 1200         first_packet = self.connection._read_packet()
#    1202         if first_packet.is_ok_packet():
#    1203             self._read_ok_packet(first_packet)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pymysql/connections.py:772, in Connection._read_packet(self, packet_type)
#     770     if self._result is not None and self._result.unbuffered_active is True:
#     771         self._result.unbuffered_active = False
# --> 772     packet.raise_for_error()
#     773 return packet
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pymysql/protocol.py:221, in MysqlPacket.raise_for_error(self)
#     219 if DEBUG:
#     220     print("errno =", errno)
# --> 221 err.raise_mysql_exception(self._data)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pymysql/err.py:143, in raise_mysql_exception(data)
#     141 if errorclass is None:
#     142     errorclass = InternalError if errno < 1000 else OperationalError
# --> 143 raise errorclass(errno, errval)
#
# ProgrammingError: (pymysql.err.ProgrammingError) (1146, "Table 'employees.employes' doesn't exist")
# [SQL: select * from employes limit 10]
# (Background on this error at: https://sqlalche.me/e/14/f405)

# %% [markdown]
# Question 6: read the employees and titles table in two sepearte DataFrames.

# %%
url = get_db_url('employees')
employees = pd.read_sql('''
    select *
    from employees

''', url)
employees
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4        10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12
# ...        ...         ...        ...       ...    ...         ...
# 300019  499995  1958-09-24     Dekang  Lichtner      F  1993-01-12
# 300020  499996  1953-03-07       Zito      Baaz      M  1990-09-27
# 300021  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 300022  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 300023  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30
#
# [300024 rows x 6 columns]

# %%
titles = pd.read_sql('''
    select *
    from titles
''', url)
titles
# Out:
#         emp_no            title   from_date     to_date
# 0        10001  Senior Engineer  1986-06-26  9999-01-01
# 1        10002            Staff  1996-08-03  9999-01-01
# 2        10003  Senior Engineer  1995-12-03  9999-01-01
# 3        10004         Engineer  1986-12-01  1995-12-01
# 4        10004  Senior Engineer  1995-12-01  9999-01-01
# ...        ...              ...         ...         ...
# 443303  499997         Engineer  1987-08-30  1992-08-29
# 443304  499997  Senior Engineer  1992-08-29  9999-01-01
# 443305  499998     Senior Staff  1998-12-27  9999-01-01
# 443306  499998            Staff  1993-12-27  1998-12-27
# 443307  499999         Engineer  1997-11-30  9999-01-01
#
# [443308 rows x 4 columns]

# %% [markdown]
# Question 7: How many rows and columns do you have in each DataFrame? Is that what you expected?

# %%
employees.shape
# Out:
# (300024, 6)

# %%
titles.shape
# Out:
# (443308, 4)

# %% [markdown]
# Question 8: Display the summary statistics for each DataFrame.

# %%
employees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300024 entries, 0 to 300023
# Data columns (total 6 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   emp_no      300024 non-null  int64
#  1   birth_date  300024 non-null  object
#  2   first_name  300024 non-null  object
#  3   last_name   300024 non-null  object
#  4   gender      300024 non-null  object
#  5   hire_date   300024 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 13.7+ MB

# %%
titles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 443308 entries, 0 to 443307
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   emp_no     443308 non-null  int64
#  1   title      443308 non-null  object
#  2   from_date  443308 non-null  object
#  3   to_date    443308 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 13.5+ MB

# %% [markdown]
# Question 9: How many unique titles are in the titles datadrame

# %%
unique_titles = df_titles['title'].unique()
unique_df = pd.DataFrame(unique_titles)
len(unique_df)
# Out:
# 7

# %%
titles.title.nunique()
# Out:
# 7

# %%
titles.title.unique()
# Out:
# array(['Senior Engineer', 'Staff', 'Engineer', 'Senior Staff',
#        'Assistant Engineer', 'Technique Leader', 'Manager'], dtype=object)

# %% [markdown]
# Question 10: What is the oldest date in the to_date column?

# %%
titles.sort_values(by = 'to_date').head(1)
# Out:
#        emp_no     title   from_date     to_date
# 16064   20869  Engineer  1985-02-17  1985-03-01

# %%
titles.to_date.min()
# Out:
# datetime.date(1985, 3, 1)

# %%
titles['to_date'].sort_values()
# Out:
# 16064     1985-03-01
# 406358    1985-03-11
# 346216    1985-03-20
# 35527     1985-03-23
# 277603    1985-04-17
#              ...
# 191714    9999-01-01
# 191712    9999-01-01
# 191707    9999-01-01
# 191723    9999-01-01
# 443307    9999-01-01
# Name: to_date, Length: 443308, dtype: object

# %%
titles[titles.to_date == titles.to_date.min()].to_date
# Out:
# 16064    1985-03-01
# Name: to_date, dtype: object

# %% [markdown]
# Question 11: What is the most recent date in the to_date column?

# %%
# Filtering out currently employed (9999, 1, 1)
titles[titles.to_date != titles.to_date.max()].to_date.max()
# Out:
# datetime.date(2002, 8, 1)

# %% [markdown]
# ### Exercise 2

# %% [markdown]
# Question 1: Copy the useres and roles DataFrames from the examples above.

# %%
# Create the users DataFrame.

users = pd.DataFrame({
    'id': [1, 2, 3, 4, 5, 6],
    'name': ['bob', 'joe', 'sally', 'adam', 'jane', 'mike'],
    'role_id': [1, 2, 3, 3, np.nan, np.nan]
})
users
# Out:
#    id   name  role_id
# 0   1    bob      1.0
# 1   2    joe      2.0
# 2   3  sally      3.0
# 3   4   adam      3.0
# 4   5   jane      NaN
# 5   6   mike      NaN

# %%
# Create the roles DataFrame

roles = pd.DataFrame({
    'id': [1, 2, 3, 4],
    'name': ['admin', 'author', 'reviewer', 'commenter']
})
roles
# Out:
#    id       name
# 0   1      admin
# 1   2     author
# 2   3   reviewer
# 3   4  commenter

# %% [markdown]
# Question 2. What is the result of using a right join on the DataFrames

# %%
right_df = users.merge(roles, how = 'right', left_on = 'role_id', right_on = 'id')
right_df
# Out:
#    id_x name_x  role_id  id_y     name_y
# 0   1.0    bob      1.0     1      admin
# 1   2.0    joe      2.0     2     author
# 2   3.0  sally      3.0     3   reviewer
# 3   4.0   adam      3.0     3   reviewer
# 4   NaN    NaN      NaN     4  commenter

# %% [markdown]
# Question 3: What is the result of using an outer join on the DataFrames?

# %%
outer_df = users.merge(roles, how = 'outer', left_on = 'role_id', right_on = 'id')
outer_df
# Out:
#    id_x name_x  role_id  id_y     name_y
# 0   1.0    bob      1.0   1.0      admin
# 1   2.0    joe      2.0   2.0     author
# 2   3.0  sally      3.0   3.0   reviewer
# 3   4.0   adam      3.0   3.0   reviewer
# 4   5.0   jane      NaN   NaN        NaN
# 5   6.0   mike      NaN   NaN        NaN
# 6   NaN    NaN      NaN   4.0  commenter

# %% [markdown]
# Question 4: What happens if you drop the foreign keys from the DataFrames and try to merge them?

# %%
new_users = users.drop(columns= 'role_id')
new_users
# Out:
#    id   name
# 0   1    bob
# 1   2    joe
# 2   3  sally
# 3   4   adam
# 4   5   jane
# 5   6   mike

# %%
nu_merge = new_users.merge(roles, how = 'outer', left_on = 'id', right_on = 'id')
nu_merge
# Out:
#    id name_x     name_y
# 0   1    bob      admin
# 1   2    joe     author
# 2   3  sally   reviewer
# 3   4   adam  commenter
# 4   5   jane        NaN
# 5   6   mike        NaN

# %% [markdown]
# Question 5: Load the mpg dataset from PyDataset.

# %%
from pydataset import data
mpg = data('mpg')
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# 230  midsize
# 231  midsize
# 232  midsize
# 233  midsize
# 234  midsize
#
# [234 rows x 11 columns]

# %% [markdown]
# Question 6: Output and read the documentation for the mpg dataset.

# %%
data('mpg', show_doc = True)
# Out:
# mpg
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Fuel economy data from 1999 and 2008 for 38 popular models of car
#
# ### Description
#
# This dataset contains a subset of the fuel economy data that the EPA makes
# available on http://fueleconomy.gov. It contains only models which had a new
# release every year between 1999 and 2008 - this was used as a proxy for the
# popularity of the car.
#
# ### Usage
#
#     data(mpg)
#
# ### Format
#
# A data frame with 234 rows and 11 variables
#
# ### Details
#
#   * manufacturer.
#
#   * model.
#
#   * displ. engine displacement, in litres
#
#   * year.
#
#   * cyl. number of cylinders
#
#   * trans. type of transmission
#
#   * drv. f = front-wheel drive, r = rear wheel drive, 4 = 4wd
#
#   * cty. city miles per gallon
#
#   * hwy. highway miles per gallon
#
#   * fl.
#
#   * class.

# %% [markdown]
# Question 7: How many rows and columns are in the dataset?

# %%
mpg.shape
# Out:
# (234, 11)

# %% [markdown]
# Question 8: Check out your column names and perform any cleanup you may want on them.

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 234 entries, 1 to 234
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  class         234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 21.9+ KB

# %%
mpg.rename(columns={'cty':'city'}, inplace=True)
mpg.rename(columns= {'hwy':'highway'}, inplace=True)
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  city  highway fl  \
# 1         audi    a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2         audi    a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3         audi    a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4         audi    a4    2.0  2008    4    auto(av)   f    21       30  p
# 5         audi    a4    2.8  1999    6    auto(l5)   f    16       26  p
#
#      class
# 1  compact
# 2  compact
# 3  compact
# 4  compact
# 5  compact

# %% [markdown]
# Question 9: Display the summary statistics for the dataset.

# %%
mpg.describe()
# Out:
#             displ         year         cyl        city     highway
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %% [markdown]
# Question 10: How many different manufacturers are there?

# %%
mpg.manufacturer.nunique()
# Out:
# 15

# %% [markdown]
# Question 11: How many different models are there?

# %%
mpg.model.nunique()
# Out:
# 38

# %% [markdown]
# Question 12: Create a column named mileage_difference like you did in the DataFrames exercises; this column should contain the difference between highway and city mileage for each car.

# %%
mpg['mileage_difference'] = mpg.highway - mpg.city
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  city  highway fl  \
# 1         audi    a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2         audi    a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3         audi    a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4         audi    a4    2.0  2008    4    auto(av)   f    21       30  p
# 5         audi    a4    2.8  1999    6    auto(l5)   f    16       26  p
#
#      class  mileage_difference
# 1  compact                  11
# 2  compact                   8
# 3  compact                  11
# 4  compact                   9
# 5  compact                  10

# %% [markdown]
# Question 13: Create a column named average_mileage like you did in the DataFrames exercises; this is the mean of the city and highway mileage.

# %%
mpg['average_mileage'] = (mpg.highway + mpg.city) /2
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  city  highway fl  \
# 1         audi    a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2         audi    a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3         audi    a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4         audi    a4    2.0  2008    4    auto(av)   f    21       30  p
# 5         audi    a4    2.8  1999    6    auto(l5)   f    16       26  p
#
#      class  mileage_difference  average_mileage
# 1  compact                  11             23.5
# 2  compact                   8             25.0
# 3  compact                  11             25.5
# 4  compact                   9             25.5
# 5  compact                  10             21.0

# %% [markdown]
# Question 14: Create a new column on the mpg dataset named is_automatic that holds boolean values denoting whether the car has an automatic transmission.

# %%
# .startswith() = test if the start of each string element matches a pattern
mpg[mpg.trans == mpg.trans.str.startswith('auto')]
mpg.head(10)
# Out:
#    manufacturer       model  displ  year  cyl       trans drv  city  highway  \
# 1          audi          a4    1.8  1999    4    auto(l5)   f    18       29
# 2          audi          a4    1.8  1999    4  manual(m5)   f    21       29
# 3          audi          a4    2.0  2008    4  manual(m6)   f    20       31
# 4          audi          a4    2.0  2008    4    auto(av)   f    21       30
# 5          audi          a4    2.8  1999    6    auto(l5)   f    16       26
# 6          audi          a4    2.8  1999    6  manual(m5)   f    18       26
# 7          audi          a4    3.1  2008    6    auto(av)   f    18       27
# 8          audi  a4 quattro    1.8  1999    4  manual(m5)   4    18       26
# 9          audi  a4 quattro    1.8  1999    4    auto(l5)   4    16       25
# 10         audi  a4 quattro    2.0  2008    4  manual(m6)   4    20       28
#
#    fl    class  mileage_difference  average_mileage  is_automatic
# 1   p  compact                  11             23.5          True
# 2   p  compact                   8             25.0         False
# 3   p  compact                  11             25.5         False
# 4   p  compact                   9             25.5          True
# 5   p  compact                  10             21.0          True
# 6   p  compact                   8             22.0         False
# 7   p  compact                   9             22.5          True
# 8   p  compact                   8             22.0         False
# 9   p  compact                   9             20.5          True
# 10  p  compact                   8             24.0         False

# %% [markdown]
# Questoin 15: Using the mpg dataset, find out which which manufacturer has the best miles per gallon on average?

# %%
pd.DataFrame(mpg.groupby('manufacturer').average_mileage.mean()).sort_values(by='average_mileage', ascending = False)
# Out:
#               average_mileage
# manufacturer
# honda               28.500000
# volkswagen          25.074074
# hyundai             22.750000
# subaru              22.428571
# audi                22.027778
# toyota              21.720588
# pontiac             21.700000
# nissan              21.346154
# chevrolet           18.447368
# ford                16.680000
# mercury             15.625000
# jeep                15.562500
# dodge               15.540541
# lincoln             14.166667
# land rover          14.000000

# %% [markdown]
# Question 16: Do automatic or manual cars have better miles per gallon?

# %%
pd.DataFrame(mpg.groupby('is_automatic').average_mileage.mean()).sort_values(by='average_mileage', ascending = False)
# Out:
#               average_mileage
# is_automatic
# False               22.227273
# True                19.130573

# %% [markdown]
# ### Exercise III

# %% [markdown]
# Question 1: Use your get_db_url function to help you explore the data from chipotle database.

# %%
import env
url = get_db_url('chipotle')

# %%
orders = pd.read_sql('select * from orders', url)
orders
# Out:
#         id  order_id  quantity                              item_name  \
# 0        1         1         1           Chips and Fresh Tomato Salsa
# 1        2         1         1                                   Izze
# 2        3         1         1                       Nantucket Nectar
# 3        4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4        5         2         2                           Chicken Bowl
# ...    ...       ...       ...                                    ...
# 4617  4618      1833         1                          Steak Burrito
# 4618  4619      1833         1                          Steak Burrito
# 4619  4620      1834         1                     Chicken Salad Bowl
# 4620  4621      1834         1                     Chicken Salad Bowl
# 4621  4622      1834         1                     Chicken Salad Bowl
#
#                                                                      choice_description  \
# 0                                                                                   nan
# 1                                                                          [Clementine]
# 2                                                                               [Apple]
# 3                                                                                   nan
# 4            [Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]
# ...                                                                                 ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour Cream, Cheese, Lettuce, Guacamole]]
# 4618               [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese, Lettuce, Guacamole]]
# 4619         [Fresh Tomato Salsa, [Fajita Vegetables, Pinto Beans, Guacamole, Lettuce]]
# 4620                                 [Fresh Tomato Salsa, [Fajita Vegetables, Lettuce]]
# 4621                    [Fresh Tomato Salsa, [Fajita Vegetables, Pinto Beans, Lettuce]]
#
#      item_price
# 0        $2.39
# 1        $3.39
# 2        $3.39
# 3        $2.39
# 4       $16.98
# ...         ...
# 4617    $11.75
# 4618    $11.75
# 4619    $11.25
# 4620     $8.75
# 4621     $8.75
#
# [4622 rows x 6 columns]

# %% [markdown]
# Question 2: What is the total price for each order?

# %%
orders
# Out:
#         id  order_id  quantity                              item_name  \
# 0        1         1         1           Chips and Fresh Tomato Salsa
# 1        2         1         1                                   Izze
# 2        3         1         1                       Nantucket Nectar
# 3        4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4        5         2         2                           Chicken Bowl
# ...    ...       ...       ...                                    ...
# 4617  4618      1833         1                          Steak Burrito
# 4618  4619      1833         1                          Steak Burrito
# 4619  4620      1834         1                     Chicken Salad Bowl
# 4620  4621      1834         1                     Chicken Salad Bowl
# 4621  4622      1834         1                     Chicken Salad Bowl
#
#                                                                      choice_description  \
# 0                                                                                   nan
# 1                                                                          [Clementine]
# 2                                                                               [Apple]
# 3                                                                                   nan
# 4            [Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]
# ...                                                                                 ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour Cream, Cheese, Lettuce, Guacamole]]
# 4618               [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese, Lettuce, Guacamole]]
# 4619         [Fresh Tomato Salsa, [Fajita Vegetables, Pinto Beans, Guacamole, Lettuce]]
# 4620                                 [Fresh Tomato Salsa, [Fajita Vegetables, Lettuce]]
# 4621                    [Fresh Tomato Salsa, [Fajita Vegetables, Pinto Beans, Lettuce]]
#
#      item_price
# 0        $2.39
# 1        $3.39
# 2        $3.39
# 3        $2.39
# 4       $16.98
# ...         ...
# 4617    $11.75
# 4618    $11.75
# 4619    $11.25
# 4620     $8.75
# 4621     $8.75
#
# [4622 rows x 6 columns]

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  4622 non-null   int64
#  1   order_id            4622 non-null   int64
#  2   quantity            4622 non-null   int64
#  3   item_name           4622 non-null   object
#  4   choice_description  4622 non-null   object
#  5   item_price          4622 non-null   object
#  6   total_price         4622 non-null   object
# dtypes: int64(3), object(4)
# memory usage: 252.9+ KB

# %%
def remove_issues(price):
    #remove commas from the string
    no_spaces = price.replace(',','')
    #remove dollar signs
    no_sign = no_spaces.replace('$','')
    return no_sign

# %%
orders['item_price'] = orders['item_price'].apply(remove_issues).astype(float)
orders
# Out:
#         id  order_id  quantity                              item_name  \
# 0        1         1         1           Chips and Fresh Tomato Salsa
# 1        2         1         1                                   Izze
# 2        3         1         1                       Nantucket Nectar
# 3        4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4        5         2         2                           Chicken Bowl
# ...    ...       ...       ...                                    ...
# 4617  4618      1833         1                          Steak Burrito
# 4618  4619      1833         1                          Steak Burrito
# 4619  4620      1834         1                     Chicken Salad Bowl
# 4620  4621      1834         1                     Chicken Salad Bowl
# 4621  4622      1834         1                     Chicken Salad Bowl
#
#                                                                      choice_description  \
# 0                                                                                   nan
# 1                                                                          [Clementine]
# 2                                                                               [Apple]
# 3                                                                                   nan
# 4            [Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]
# ...                                                                                 ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour Cream, Cheese, Lettuce, Guacamole]]
# 4618               [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese, Lettuce, Guacamole]]
# 4619         [Fresh Tomato Salsa, [Fajita Vegetables, Pinto Beans, Guacamole, Lettuce]]
# 4620                                 [Fresh Tomato Salsa, [Fajita Vegetables, Lettuce]]
# 4621                    [Fresh Tomato Salsa, [Fajita Vegetables, Pinto Beans, Lettuce]]
#
#       item_price
# 0           2.39
# 1           3.39
# 2           3.39
# 3           2.39
# 4          16.98
# ...          ...
# 4617       11.75
# 4618       11.75
# 4619       11.25
# 4620        8.75
# 4621        8.75
#
# [4622 rows x 6 columns]

# %%
orders['total_price'] = orders.quantity * orders.item_price
orders
# Out:
#         id  order_id  quantity                              item_name  \
# 0        1         1         1           Chips and Fresh Tomato Salsa
# 1        2         1         1                                   Izze
# 2        3         1         1                       Nantucket Nectar
# 3        4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4        5         2         2                           Chicken Bowl
# ...    ...       ...       ...                                    ...
# 4617  4618      1833         1                          Steak Burrito
# 4618  4619      1833         1                          Steak Burrito
# 4619  4620      1834         1                     Chicken Salad Bowl
# 4620  4621      1834         1                     Chicken Salad Bowl
# 4621  4622      1834         1                     Chicken Salad Bowl
#
#                                                                      choice_description  \
# 0                                                                                   nan
# 1                                                                          [Clementine]
# 2                                                                               [Apple]
# 3                                                                                   nan
# 4            [Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]
# ...                                                                                 ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour Cream, Cheese, Lettuce, Guacamole]]
# 4618               [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese, Lettuce, Guacamole]]
# 4619         [Fresh Tomato Salsa, [Fajita Vegetables, Pinto Beans, Guacamole, Lettuce]]
# 4620                                 [Fresh Tomato Salsa, [Fajita Vegetables, Lettuce]]
# 4621                    [Fresh Tomato Salsa, [Fajita Vegetables, Pinto Beans, Lettuce]]
#
#       item_price  total_price
# 0           2.39         2.39
# 1           3.39         3.39
# 2           3.39         3.39
# 3           2.39         2.39
# 4          16.98        33.96
# ...          ...          ...
# 4617       11.75        11.75
# 4618       11.75        11.75
# 4619       11.25        11.25
# 4620        8.75         8.75
# 4621        8.75         8.75
#
# [4622 rows x 7 columns]

# %%
pd.DataFrame(orders.groupby('order_id').total_price.sum()).sort_values(by = 'total_price', ascending=False)
# Out:
#           total_price
# order_id
# 1443          1074.24
# 511            315.29
# 1559           246.00
# 1660           222.75
# 926            205.25
# ...               ...
# 1122            10.08
# 1093            10.08
# 614             10.08
# 1014            10.08
# 393             10.08
#
# [1834 rows x 1 columns]

# %% [markdown]
# Question 3: What are the most popular 3 items?

# %%
pd.DataFrame(orders.groupby('item_name').quantity.sum()).sort_values(by = 'quantity', ascending=False).head(3)
# Out:
#                      quantity
# item_name
# Chicken Bowl              761
# Chicken Burrito           591
# Chips and Guacamole       506

# %% [markdown]
# Question 4: Which item has produced the most revenue?

# %%
pd.DataFrame(orders.groupby('item_name').item_price.sum()).sort_values(by = 'item_price', ascending=False)
# Out:
#                                        item_price
# item_name
# Chicken Bowl                              7342.73
# Chicken Burrito                           5575.82
# Steak Burrito                             3851.43
# Steak Bowl                                2260.19
# Chips and Guacamole                       2201.04
# Chicken Salad Bowl                        1228.75
# Chicken Soft Tacos                        1108.09
# Veggie Burrito                             934.77
# Barbacoa Burrito                           894.75
# Veggie Bowl                                867.99
# Carnitas Bowl                              736.71
# Barbacoa Bowl                              672.36
# Carnitas Burrito                           597.83
# Steak Soft Tacos                           536.05
# Chips                                      494.34
# Chicken Crispy Tacos                       472.13
# Canned Soft Drink                          438.75
# Carnitas Soft Tacos                        375.94
# Chips and Fresh Tomato Salsa               361.36
# Steak Crispy Tacos                         357.34
# 6 Pack Soft Drink                          356.95
# Steak Salad Bowl                           343.59
# Bottled Water                              302.56
# Barbacoa Soft Tacos                        250.46
# Side of Chips                              185.90
# Veggie Salad Bowl                          182.50
# Chips and Tomatillo Red Chili Salsa        147.50
# Canned Soda                                137.34
# Chips and Tomatillo Green Chili Salsa      132.75
# Barbacoa Crispy Tacos                      120.21
# Barbacoa Salad Bowl                        106.40
# Nantucket Nectar                            98.31
# Chicken Salad                               81.09
# Chips and Tomatillo-Green Chili Salsa       78.87
# Carnitas Crispy Tacos                       77.96
# Veggie Soft Tacos                           73.96
# Chips and Roasted Chili Corn Salsa          67.85
# Izze                                        67.80
# Carnitas Salad Bowl                         66.34
# Chips and Tomatillo-Red Chili Salsa         59.75
# Veggie Salad                                50.94
# Burrito                                     44.40
# Chips and Roasted Chili-Corn Salsa          43.02
# Steak Salad                                 35.66
# Bowl                                        29.60
# Salad                                       14.80
# Crispy Tacos                                14.80
# Carnitas Salad                               8.99
# Veggie Crispy Tacos                          8.49
# Chips and Mild Fresh Tomato Salsa            3.00

# %% [markdown]
# Question 5: Join the employees and titles DataFrames toghter.

# %%
url_employees = get_db_url('employees')

# %%
employees = pd.read_sql('select * from employees', url_employees)
employees
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4        10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12
# ...        ...         ...        ...       ...    ...         ...
# 300019  499995  1958-09-24     Dekang  Lichtner      F  1993-01-12
# 300020  499996  1953-03-07       Zito      Baaz      M  1990-09-27
# 300021  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 300022  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 300023  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30
#
# [300024 rows x 6 columns]

# %%
titles = pd.read_sql('select * from titles', url_employees)
titles
# Out:
#         emp_no            title   from_date     to_date
# 0        10001  Senior Engineer  1986-06-26  9999-01-01
# 1        10002            Staff  1996-08-03  9999-01-01
# 2        10003  Senior Engineer  1995-12-03  9999-01-01
# 3        10004         Engineer  1986-12-01  1995-12-01
# 4        10004  Senior Engineer  1995-12-01  9999-01-01
# ...        ...              ...         ...         ...
# 443303  499997         Engineer  1987-08-30  1992-08-29
# 443304  499997  Senior Engineer  1992-08-29  9999-01-01
# 443305  499998     Senior Staff  1998-12-27  9999-01-01
# 443306  499998            Staff  1993-12-27  1998-12-27
# 443307  499999         Engineer  1997-11-30  9999-01-01
#
# [443308 rows x 4 columns]

# %%
combined_df = pd.merge(employees, titles, how='outer', left_on='emp_no', right_on='emp_no')
combined_df
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date  \
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# ...        ...         ...        ...       ...    ...         ...
# 443303  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 443304  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 443305  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 443306  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 443307  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30
#
#                   title   from_date     to_date
# 0       Senior Engineer  1986-06-26  9999-01-01
# 1                 Staff  1996-08-03  9999-01-01
# 2       Senior Engineer  1995-12-03  9999-01-01
# 3              Engineer  1986-12-01  1995-12-01
# 4       Senior Engineer  1995-12-01  9999-01-01
# ...                 ...         ...         ...
# 443303         Engineer  1987-08-30  1992-08-29
# 443304  Senior Engineer  1992-08-29  9999-01-01
# 443305     Senior Staff  1998-12-27  9999-01-01
# 443306            Staff  1993-12-27  1998-12-27
# 443307         Engineer  1997-11-30  9999-01-01
#
# [443308 rows x 9 columns]

# %% [markdown]
# Question 6: For each titles, find the hire date of the employee that was hired most recently with that title.

# %%
combined_df
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date  \
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# ...        ...         ...        ...       ...    ...         ...
# 443303  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 443304  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 443305  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 443306  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 443307  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30
#
#                   title   from_date     to_date
# 0       Senior Engineer  1986-06-26  9999-01-01
# 1                 Staff  1996-08-03  9999-01-01
# 2       Senior Engineer  1995-12-03  9999-01-01
# 3              Engineer  1986-12-01  1995-12-01
# 4       Senior Engineer  1995-12-01  9999-01-01
# ...                 ...         ...         ...
# 443303         Engineer  1987-08-30  1992-08-29
# 443304  Senior Engineer  1992-08-29  9999-01-01
# 443305     Senior Staff  1998-12-27  9999-01-01
# 443306            Staff  1993-12-27  1998-12-27
# 443307         Engineer  1997-11-30  9999-01-01
#
# [443308 rows x 9 columns]

# %%
combined_df.groupby('title').hire_date.max()
# Out:
# title
# Assistant Engineer    1999-12-24
# Engineer              2000-01-28
# Manager               1992-02-05
# Senior Engineer       2000-01-01
# Senior Staff          2000-01-13
# Staff                 2000-01-12
# Technique Leader      1999-12-31
# Name: hire_date, dtype: object

# %%
# max is acting the entire data frame. 
combined_df.groupby('title').max()
# Out:
#                     emp_no  birth_date first_name last_name gender  \
# title
# Assistant Engineer  499974  1965-02-01     Zvonko   dAstous      M
# Engineer            499999  1965-02-01     Zvonko   dAstous      M
# Manager             111939  1964-04-25    Yuchang     Zhang      M
# Senior Engineer     499997  1965-02-01     Zvonko   dAstous      M
# Senior Staff        499998  1965-02-01     Zvonko   dAstous      M
# Staff               499998  1965-02-01     Zvonko   dAstous      M
# Technique Leader    499942  1965-02-01     Zvonko   dAstous      M
#
#                      hire_date   from_date     to_date
# title
# Assistant Engineer  1999-12-24  2000-02-01  9999-01-01
# Engineer            2000-01-28  2002-08-01  9999-01-01
# Manager             1992-02-05  1996-08-30  9999-01-01
# Senior Engineer     2000-01-01  2002-08-01  9999-01-01
# Senior Staff        2000-01-13  2002-08-01  9999-01-01
# Staff               2000-01-12  2000-02-01  9999-01-01
# Technique Leader    1999-12-31  2000-02-01  9999-01-01

# %%
# max is acting the entire data frame. 
combined_df.groupby('title').max()[['hire_date']]
# Out:
#                      hire_date
# title
# Assistant Engineer  1999-12-24
# Engineer            2000-01-28
# Manager             1992-02-05
# Senior Engineer     2000-01-01
# Senior Staff        2000-01-13
# Staff               2000-01-12
# Technique Leader    1999-12-31

# %% [markdown]
# Question 7: Write the code necessary to create a cross tabulation of the number of titles by department. (Hint: this will involve a combination of SQL code to pull the necessary data and python/pandas code to perform the manipulations.)

# %%
query = '''
select
	dept_name,
    title, 
    emp_no
from 
	departments
    join dept_emp
		using(dept_no)
	join titles
		using(emp_no)
        '''

# %%
titles_by_dept = pd.read_sql(query, url_employees)
titles_by_dept
# Out:
#                dept_name         title  emp_no
# 0       Customer Service         Staff   10011
# 1       Customer Service  Senior Staff   10038
# 2       Customer Service         Staff   10038
# 3       Customer Service  Senior Staff   10049
# 4       Customer Service         Staff   10049
# ...                  ...           ...     ...
# 489898             Sales  Senior Staff  499986
# 489899             Sales         Staff  499986
# 489900             Sales         Staff  499987
# 489901             Sales  Senior Staff  499988
# 489902             Sales         Staff  499988
#
# [489903 rows x 3 columns]

# %%
pd.crosstab(titles_by_dept.title, titles_by_dept.dept_name)
# Out:
# dept_name           Customer Service  Development  Finance  Human Resources  \
# title
# Assistant Engineer               298         7769        0                0
# Engineer                        2362        58135        0                0
# Manager                            4            2        2                2
# Senior Engineer                 2027        49326        0                0
# Senior Staff                   13925         1247    12139            12274
# Staff                          16150         1424    13929            14342
# Technique Leader                 309         7683        0                0
#
# dept_name           Marketing  Production  Quality Management  Research  Sales
# title
# Assistant Engineer          0        6445                1831       378      0
# Engineer                    0       49649               13852      2986      0
# Manager                     2           4                   4         2      2
# Senior Engineer             0       42205               11864      2570      0
# Senior Staff            13940        1270                   0     11637  36191
# Staff                   16196        1478                   0     13495  41808
# Technique Leader            0        6557                1795       393      0

# %%
#table by sql to cross referance
query_2 = '''
select
	dept_name,
    title, 
    count(emp_no) as number_of_employees
from 
	departments
    join dept_emp
		using(dept_no)
	join titles
		using(emp_no)
group by
    dept_name, title;
        '''

# %%
titles_by_dept_2 = pd.read_sql(query_2, url_employees)
titles_by_dept_2
# Out:
#              dept_name               title  number_of_employees
# 0     Customer Service               Staff                16150
# 1     Customer Service        Senior Staff                13925
# 2     Customer Service            Engineer                 2362
# 3     Customer Service     Senior Engineer                 2027
# 4     Customer Service  Assistant Engineer                  298
# 5     Customer Service    Technique Leader                  309
# 6     Customer Service             Manager                    4
# 7          Development     Senior Engineer                49326
# 8          Development  Assistant Engineer                 7769
# 9          Development            Engineer                58135
# 10         Development    Technique Leader                 7683
# 11         Development        Senior Staff                 1247
# 12         Development               Staff                 1424
# 13         Development             Manager                    2
# 14             Finance        Senior Staff                12139
# 15             Finance               Staff                13929
# 16             Finance             Manager                    2
# 17     Human Resources        Senior Staff                12274
# 18     Human Resources               Staff                14342
# 19     Human Resources             Manager                    2
# 20           Marketing        Senior Staff                13940
# 21           Marketing               Staff                16196
# 22           Marketing             Manager                    2
# 23          Production     Senior Engineer                42205
# 24          Production            Engineer                49649
# 25          Production  Assistant Engineer                 6445
# 26          Production    Technique Leader                 6557
# 27          Production        Senior Staff                 1270
# 28          Production               Staff                 1478
# 29          Production             Manager                    4
# 30  Quality Management  Assistant Engineer                 1831
# 31  Quality Management            Engineer                13852
# 32  Quality Management     Senior Engineer                11864
# 33  Quality Management    Technique Leader                 1795
# 34  Quality Management             Manager                    4
# 35            Research        Senior Staff                11637
# 36            Research               Staff                13495
# 37            Research            Engineer                 2986
# 38            Research     Senior Engineer                 2570
# 39            Research    Technique Leader                  393
# 40            Research  Assistant Engineer                  378
# 41            Research             Manager                    2
# 42               Sales               Staff                41808
# 43               Sales        Senior Staff                36191
# 44               Sales             Manager                    2
